# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Advanced Stress Testing Analysis"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "from src.data_preparation import DataPreparation\n",
    "from src.stress_testing import StressTesting\n",
    "from src.risk_analysis import RiskAnalysis\n",
    "from src.visualization import Visualization\n",
    "\n",
    "# Load Data\n",
    "portfolio_data = DataPreparation.load_data(\"../data/inputs/portfolio_data.csv\")\n",
    "market_data = DataPreparation.load_data(\"../data/inputs/market_data.csv\")\n",
    "stress_scenarios = DataPreparation.load_data(\"../data/inputs/stress_scenarios.csv\")\n",
    "\n",
    "# Preprocess Data\n",
    "portfolio_data = DataPreparation.preprocess_data(portfolio_data)\n",
    "market_data = DataPreparation.preprocess_data(market_data)\n",
    "\n",
    "# Stress Testing\n",
    "tester = StressTesting(portfolio_data, market_data, stress_scenarios)\n",
    "results = tester.run_all_scenarios()\n",
    "\n",
    "# Risk Analysis\n",
    "losses = results.mean(axis=1)\n",
    "var = RiskAnalysis.calculate_var(losses)\n",
    "es = RiskAnalysis.calculate_es(losses)\n",
    "print(f\"Value at Risk (VaR): {var}\")\n",
    "print(f\"Expected Shortfall (ES): {es}\")\n",
    "\n",
    "# Visualization\n",
    "Visualization.plot_scenario_impacts(results)\n",
    "Visualization.plot_loss_distribution(losses, title=\"Advanced Portfolio Loss Distribution\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
