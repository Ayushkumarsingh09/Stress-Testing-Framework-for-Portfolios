# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Stress Testing Framework - Demo"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "from src.data_preparation import DataPreparation\n",
    "from src.stress_testing import StressTesting\n",
    "from src.visualization import Visualization\n",
    "\n",
    "# Load Data\n",
    "portfolio_data = DataPreparation.load_data(\"../data/inputs/portfolio_data.csv\")\n",
    "market_data = DataPreparation.load_data(\"../data/inputs/market_data.csv\")\n",
    "stress_scenarios = DataPreparation.load_data(\"../data/inputs/stress_scenarios.csv\")\n",
    "\n",
    "# Clean Data\n",
    "portfolio_data = DataPreparation.clean_data(portfolio_data)\n",
    "market_data = DataPreparation.clean_data(market_data)\n",
    "stress_scenarios = DataPreparation.clean_data(stress_scenarios)\n",
    "\n",
    "# Stress Testing\n",
    "tester = StressTesting(portfolio_data, market_data, stress_scenarios)\n",
    "results = tester.run_all_scenarios()\n",
    "print(results)\n",
    "\n",
    "# Visualization\n",
    "Visualization.plot_scenario_impacts(results)\n",
    "Visualization.plot_loss_distribution(results.mean(axis=1))"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
